# %% [markdown]
# # 경쟁사 고객 리뷰 분석으로 소비자 인식 조사
# 영양제 브랜드 자사와 경쟁사의 구매 후기를 분석해서 소비자들의 인식을 조사해봅니다.

# %% [markdown]
# ## 데이터 설명
# 데이터는 다음의 링크에서 다운받으실 수 있습니다.
#
#
# ---
#
# * [센트룸 구매후기](https://drive.google.com/file/d/1eeTHELYDR0UW9CK7yODGhcUGylTfpLv4/view?usp=sharing)
# *  [세노비스 카페 데이터](https://drive.google.com/file/d/1798xQJmU2rIlqiLyoUcIhelGV9szjLUu/view?usp=sharing)
# * [센트룸 카페 데이터](https://drive.google.com/file/d/1RFYWzhrMGongGVMIEvs1gaMOi-PmAfuz/view?usp=sharing)
#
# ---

# %% [markdown]
# # 텍스트 마이닝을 위한 전처리
# ## KoNLP를 이용한 형태소 분석
# - KoNLPy가 제공하는 형태소분석기 중 하나인 Kkma를 사용합니다.
# - 자세한 내용은 http://konlpy.org/ko/v0.4.3/morph/ 참조

# %%
# KoNLPy 라이브러리 설치. 최초 1회만 실행
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.6/dist-packages (0.5.2)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (3.8.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.18.2)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from konlpy) (0.4.3)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (0.7.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.12.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.21.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)

# %% [markdown]
# # 형태소 분석기
# - 한나눔 http://semanticweb.kaist.ac.kr/hannanum/index.html
# - 트위터 https://github.com/twitter/twitter-korean-text
# - 꼬꼬마 http://kkma.snu.ac.kr/documents/
#
# ## 형태소분석기의 성능차이
# ![대체 텍스트](http://konlpy.org/ko/v0.4.2/_images/time.png)
# * 출처: http://konlpy.org/ko/v0.4.2/morph/

# %%
from konlpy.tag import Hannanum
from konlpy.tag import Twitter
from konlpy.tag import Kkma
hannanum=Hannanum()
twitter=Twitter()
kkma = Kkma()
# Out:
# /usr/local/lib/python3.6/dist-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %% [markdown]
# ### 꼬꼬마 형태소 분석기
# - 문장을 형태소 단위로 분리하고 품사를 태깅합니다
# - 품사태그는 일반명사(NNG), 고유명사(NNP), 동사(VV), 형용사(VA) 등이 있습니다
# - http://kkma.snu.ac.kr/documents/index.jsp?doc=postag 형태소 리스트를 확인

# %%
print(kkma.sentences(u'아버지가 방에 들어가셨다. 아버지 가방에 들어가셨다. 아버지가 방 안에 있는 가방에 들어가셨다.'))
# Out:
# ['아버지가 방에 들어가셨다.', '아버지 가방에 들어가셨다.', '아버지가 방 안에 있는 가방에 들어가셨다.']

# %%
print(kkma.pos(u'아버지가 방에 들어가셨다. 아버지 가방에 들어가셨다. 아버지가 방 안에 있는 가방에 들어가셨다.'))
# Out:
# [('아버지', 'NNG'), ('가', 'JKS'), ('방', 'NNG'), ('에', 'JKM'), ('들어가', 'VV'), ('시', 'EPH'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('아버지', 'NNG'), ('가방', 'NNG'), ('에', 'JKM'), ('들어가', 'VV'), ('시', 'EPH'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('아버지', 'NNG'), ('가', 'JKS'), ('방', 'NNG'), ('안', 'NNG'), ('에', 'JKM'), ('있', 'VV'), ('는', 'ETD'), ('가방', 'NNG'), ('에', 'JKM'), ('들어가', 'VV'), ('시', 'EPH'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF')]

# %% [markdown]
# ### 한나눔 형태소 분석기

# %%
print(hannanum.pos(u'아버지가 방에 들어가셨다. 아버지 가방에 들어가셨다. 아버지가 방 안에 있는 가방에 들어가셨다.'))
# Out:
# [('아버지', 'N'), ('가', 'J'), ('방', 'N'), ('에', 'J'), ('들', 'P'), ('어', 'E'), ('가', 'P'), ('셨다', 'E'), ('.', 'S'), ('아버지', 'N'), ('가방', 'N'), ('에', 'J'), ('들', 'P'), ('어', 'E'), ('가', 'P'), ('셨다', 'E'), ('.', 'S'), ('아버지', 'N'), ('가', 'J'), ('방', 'N'), ('안', 'N'), ('에', 'J'), ('있', 'P'), ('는', 'E'), ('가방', 'N'), ('에', 'J'), ('들', 'P'), ('어', 'E'), ('가', 'P'), ('셨다', 'E'), ('.', 'S')]

# %% [markdown]
# ### 트위터 형태소 분석기

# %%
print(twitter.pos('아버지가 방에 들어가셨다. 아버지 가방에 들어가셨다. 아버지가 방 안에 있는 가방에 들어가셨다.'))
# Out:
# [('아버지', 'Noun'), ('가', 'Josa'), ('방', 'Noun'), ('에', 'Josa'), ('들어가셨다', 'Verb'), ('.', 'Punctuation'), ('아버지', 'Noun'), ('가방', 'Noun'), ('에', 'Josa'), ('들어가셨다', 'Verb'), ('.', 'Punctuation'), ('아버지', 'Noun'), ('가', 'Josa'), ('방', 'Noun'), ('안', 'Noun'), ('에', 'Josa'), ('있는', 'Adjective'), ('가방', 'Noun'), ('에', 'Josa'), ('들어가셨다', 'Verb'), ('.', 'Punctuation')]

# %% [markdown]
# # 텍스트 마이닝 분석 및 시각화
# * 센트룸 데이터를 먼저 분석해봅니다.

# %% [markdown]
# ### 데이터 탐색 및 전처리

# %%
# 데이터를 불러옵니다.
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9f5b515a-0560-45cc-beea-9e1a1e527e04" name="files[]" multiple disabled />
#      <output id="result-9f5b515a-0560-45cc-beea-9e1a1e527e04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving centrum_review.txt to centrum_review (3).txt

# %%
# 형태소분석 - kkma 명사 
line_list = []
f = open("centrum_review.txt", encoding="utf-8")
for line in f:
    line = kkma.nouns(line)
    line_list.append(line)
f.close()

print("- 불러온 문서 :", len(line_list), "문장")
# Out:
# - 불러온 문서 : 102 문장

# %%
line_list[10]
# Out:
# ['플라스틱', '포장', '과대', '과대포장', '상품', '상품자체', '자체', '투명']

# %%
word_frequency = {}
noun_list = []
#불용어 리스트를 여기에 추가합니다.
stop_list = ["배송", "만족"]
line_number = 0
for line in line_list[:]:
    line_number += 1
    print(str(line_number) + "/" + str(len(line_list)), end="\r")
    noun = []
    for word in line:
        if word.split("/")[0] not in stop_list and len(word.split("/")[0]) > 1:  
            noun.append(word.split("/")[0])
            if word not in word_frequency.keys():
                word_frequency[word] = 1
            else:
                word_frequency[word] += 1
    noun_list.extend(noun)
# Out:
# 102/102

# %%
#단어별 출현빈도를 출력합니다.
word_count = []
for n, freq in word_frequency.items():
    word_count.append([n, freq])
word_count.sort(key=lambda elem: elem[1], reverse=True)
for n, freq in word_count[:10]:
    print(n + "\t" + str(freq))
# Out:
# 감사	9
# 구매	7
# 비타민	7
# 추천	5
# 건강	4
# 가격	4
# 번째	3
# 적극	3
# 피곤	3
# 이용	3

# %%
#추출한 명사 리스트를 활용해 명사만으로 이루어진 문서를 생성합니다.
noun_doc = ' '.join(noun_list)
noun_doc = noun_doc.strip()

# %% [markdown]
# * 서체 다운로드
# - 시각화에서 서체 변경만으로도 완성도를 높일 수 있습니다.
# - [다음의 링크](https://drive.google.com/file/d/1ULZI7vTml7mVVrM3fbo4AW8xhyETDETx/view?usp=sharing)에서 나눔스퀘어 서체를 다운로드 받아주세요.
# - 참고: https://hangeul.naver.com/2017/nanum

# %%
# 워드클라우드 시각화
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt

#폰트업로드
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-7f52064e-7e9f-4fda-9d8c-fefba4a2c2bc" name="files[]" multiple disabled />
#      <output id="result-7f52064e-7e9f-4fda-9d8c-fefba4a2c2bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving NanumSquareB.otf to NanumSquareB (4).otf
# User uploaded file "NanumSquareB.otf" with length 514816 bytes

# %%
#워드클라우드 파라미터 설정
font_path="NanumSquareB.otf"  #폰트
background_color="white"      #배경색
margin=3                     #모서리 여백 넓이
min_font_size=7              #최소 글자 크기
max_font_size=150             #최대 글자 크기
width=500                     #이미지 가로 크기
height=500                    #이미지 세로 크기
wc = WordCloud(font_path=font_path, background_color=background_color, margin=margin, \
               min_font_size=min_font_size, max_font_size=max_font_size, width=width, height=height)
wc.generate(noun_doc)

plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# 데이터를 불러옵니다.
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a77e0546-266e-42e9-9971-e50aded1438f" name="files[]" multiple disabled />
#      <output id="result-a77e0546-266e-42e9-9971-e50aded1438f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving centrum2.txt to centrum2.txt

# %%
# 형태소분석 - kkma 명사 
line_list = []
f = open("centrum2.txt", encoding="utf-8")
for line in f:
    line = kkma.nouns(line)
    line_list.append(line)
f.close()

print("- 불러온 문서 :", len(line_list), "문장")
# Out:
# - 불러온 문서 : 2000 문장

# %%
word_frequency = {}
noun_list = []
#불용어 리스트를 여기에 추가합니다.
stop_list = ["배송", "만족", "카페", "카페규정", "확인", "주수", "센트"]
line_number = 0
for line in line_list[:]:
    line_number += 1
    print(str(line_number) + "/" + str(len(line_list)), end="\r")
    noun = []
    for word in line:
        if word.split("/")[0] not in stop_list and len(word.split("/")[0]) > 1:  
            noun.append(word.split("/")[0])
            if word not in word_frequency.keys():
                word_frequency[word] = 1
            else:
                word_frequency[word] += 1
    noun_list.extend(noun)

# %%
#단어별 출현빈도를 출력합니다.
word_count = []
for n, freq in word_frequency.items():
    word_count.append([n, freq])
word_count.sort(key=lambda elem: elem[1], reverse=True)
for n, freq in word_count[:10]:
    print(n + "\t" + str(freq))
# Out:
# 센트룸	1841
# 비타민	786
# 임신	344
# 영양제	342
# 종합	310
# 엽산	250
# 추천	246
# 철분	221
# 종합비타민	199
# 보건소	196

# %%
#추출한 명사 리스트를 활용해 명사만으로 이루어진 문서를 생성합니다.
noun_doc = ' '.join(noun_list)
noun_doc = noun_doc.strip()

# %%
#워드클라우드 파라미터 설정
font_path="NanumSquareB.otf"  #폰트
background_color="white"      #배경색
margin=3                     #모서리 여백 넓이
min_font_size=7              #최소 글자 크기
max_font_size=150             #최대 글자 크기
width=500                     #이미지 가로 크기
height=500                    #이미지 세로 크기
wc = WordCloud(font_path=font_path, background_color=background_color, margin=margin, \
               min_font_size=min_font_size, max_font_size=max_font_size, width=width, height=height)
wc.generate(noun_doc)

plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### LDA 토픽 모델링

# %%
import gensim
from gensim import corpora
import logging
logging.basicConfig(level=logging.DEBUG)
topic = 5
keyword = 10
texts = []
resultList = []
stop_list = ["배송", "만족", "카페", "카페규정", "확인", "주수", "센트"]
for line in line_list:
    words = line
    if words != [""]:
        tokens = [word for word in words if (len(word.split("/")[0]) > 1 and word.split("/")[0] not in stop_list)]
        texts.append(tokens)
dictionary = corpora.Dictionary(texts)    
corpus = [dictionary.doc2bow(text) for text in texts]

ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=topic, id2word = dictionary, passes=10)
for num in range(topic):
    resultList.append(ldamodel.show_topic(num, keyword))
# Out:
# INFO:gensim.corpora.dictionary:adding document #0 to Dictionary(0 unique tokens: [])
# INFO:gensim.corpora.dictionary:built Dictionary(10095 unique tokens: ['16', '16주', '3개월분', '3일', '개월']...) from 2000 documents (total 46593 corpus positions)
# INFO:gensim.models.ldamodel:using symmetric alpha at 0.2
# INFO:gensim.models.ldamodel:using symmetric eta at 0.2
# INFO:gensim.models.ldamodel:using serial LDA version on this node
# INFO:gensim.models.ldamodel:running online (multi-pass) LDA training, 5 topics, 10 passes over the supplied corpus of 2000 documents, updating model once every 2000 documents, evaluating perplexity every 2000 documents, iterating 50x with a convergence threshold of 0.001000
# DEBUG:gensim.models.ldamodel:bound: at document #0
# INFO:gensim.models.ldamodel:-10.586 per-word bound, 1536.7 perplexity estimate based on a held-out corpus of 2000 documents with 46593 words
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #2000/2000
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1210/2000 documents converged within 50 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:topic #0 (0.200): 0.037*"센트룸" + 0.012*"비타민" + 0.006*"엽산" + 0.006*"신랑" + 0.006*"영양제" + 0.006*"구입" + 0.005*"추천" + 0.005*"임신" + 0.004*"철분" + 0.004*"종합"
# INFO:gensim.models.ldamodel:topic #1 (0.200): 0.018*"센트룸" + 0.007*"임신" + 0.007*"영양제" + 0.006*"비타민" + 0.005*"엽산" + 0.004*"개월" + 0.004*"구매" + 0.004*"규정" + 0.004*"지금" + 0.004*"보건소"
# INFO:gensim.models.ldamodel:topic #2 (0.200): 0.033*"센트룸" + 0.018*"비타민" + 0.011*"종합" + 0.009*"영양제" + 0.005*"종합비타민" + 0.004*"멀티" + 0.004*"신랑" + 0.004*"추천" + 0.004*"임신" + 0.003*"구입"
# INFO:gensim.models.ldamodel:topic #3 (0.200): 0.018*"센트룸" + 0.014*"비타민" + 0.006*"철분" + 0.006*"임신" + 0.005*"엽산" + 0.005*"영양제" + 0.005*"임산부" + 0.005*"게시판" + 0.005*"종합" + 0.004*"보건소"
# INFO:gensim.models.ldamodel:topic #4 (0.200): 0.052*"센트룸" + 0.019*"비타민" + 0.008*"임신" + 0.007*"추천" + 0.006*"종합" + 0.005*"복용" + 0.004*"보건소" + 0.004*"주세" + 0.004*"엽산" + 0.004*"종합비타민"
# INFO:gensim.models.ldamodel:topic diff=2.300316, rho=1.000000
# DEBUG:gensim.models.ldamodel:bound: at document #0
# INFO:gensim.models.ldamodel:-8.496 per-word bound, 361.2 perplexity estimate based on a held-out corpus of 2000 documents with 46593 words
# INFO:gensim.models.ldamodel:PROGRESS: pass 1, at document #2000/2000
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1806/2000 documents converged within 50 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:topic #0 (0.200): 0.038*"센트룸" + 0.012*"비타민" + 0.007*"신랑" + 0.006*"엽산" + 0.006*"구입" + 0.006*"영양제" + 0.005*"추천" + 0.005*"임신" + 0.004*"종합" + 0.004*"철분"
# INFO:gensim.models.ldamodel:topic #1 (0.200): 0.015*"센트룸" + 0.006*"임신" + 0.005*"영양제" + 0.005*"비타민" + 0.004*"구매" + 0.004*"규정" + 0.004*"삭제" + 0.004*"개월" + 0.004*"엽산" + 0.003*"게시판"
# INFO:gensim.models.ldamodel:topic #2 (0.200): 0.034*"센트룸" + 0.018*"비타민" + 0.010*"종합" + 0.009*"영양제" + 0.005*"종합비타민" + 0.005*"멀티" + 0.004*"신랑" + 0.004*"제품" + 0.004*"건강" + 0.003*"추천"
# INFO:gensim.models.ldamodel:topic #3 (0.200): 0.018*"센트룸" + 0.014*"비타민" + 0.007*"철분" + 0.007*"임신" + 0.006*"엽산" + 0.006*"게시판" + 0.006*"임산부" + 0.005*"보건소" + 0.005*"영양제" + 0.005*"규정"
# INFO:gensim.models.ldamodel:topic #4 (0.200): 0.058*"센트룸" + 0.022*"비타민" + 0.009*"임신" + 0.008*"추천" + 0.008*"종합" + 0.006*"복용" + 0.005*"영양제" + 0.005*"종합비타민" + 0.005*"보건소" + 0.005*"엽산"
# INFO:gensim.models.ldamodel:topic diff=0.545909, rho=0.577350
# DEBUG:gensim.models.ldamodel:bound: at document #0
# INFO:gensim.models.ldamodel:-8.277 per-word bound, 310.3 perplexity estimate based on a held-out corpus of 2000 documents with 46593 words
# INFO:gensim.models.ldamodel:PROGRESS: pass 2, at document #2000/2000
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1916/2000 documents converged within 50 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:topic #0 (0.200): 0.038*"센트룸" + 0.012*"비타민" + 0.007*"신랑" + 0.006*"구입" + 0.006*"엽산" + 0.006*"영양제" + 0.004*"추천" + 0.004*"임신" + 0.004*"종합" + 0.004*"철분"
# INFO:gensim.models.ldamodel:topic #1 (0.200): 0.013*"센트룸" + 0.005*"임신" + 0.004*"영양제" + 0.004*"비타민" + 0.004*"구매" + 0.004*"삭제" + 0.004*"규정" + 0.004*"강퇴" + 0.004*"게시판" + 0.003*"가입"
# INFO:gensim.models.ldamodel:topic #2 (0.200): 0.033*"센트룸" + 0.018*"비타민" + 0.010*"종합" + 0.009*"영양제" + 0.005*"멀티" + 0.005*"종합비타민" + 0.004*"건강" + 0.004*"신랑" + 0.004*"제품" + 0.004*"멀티비타민"
# INFO:gensim.models.ldamodel:topic #3 (0.200): 0.018*"센트룸" + 0.013*"비타민" + 0.008*"임신" + 0.008*"철분" + 0.006*"게시판" + 0.006*"엽산" + 0.006*"보건소" + 0.006*"규정" + 0.006*"임산부" + 0.005*"영양제"
# INFO:gensim.models.ldamodel:topic #4 (0.200): 0.062*"센트룸" + 0.024*"비타민" + 0.010*"임신" + 0.009*"종합" + 0.009*"추천" + 0.006*"영양제" + 0.006*"복용" + 0.006*"종합비타민" + 0.005*"엽산" + 0.005*"보건소"
# INFO:gensim.models.ldamodel:topic diff=0.355497, rho=0.500000
# DEBUG:gensim.models.ldamodel:bound: at document #0
# INFO:gensim.models.ldamodel:-8.191 per-word bound, 292.3 perplexity estimate based on a held-out corpus of 2000 documents with 46593 words
# INFO:gensim.models.ldamodel:PROGRESS: pass 3, at document #2000/2000
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1925/2000 documents converged within 50 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:topic #0 (0.200): 0.038*"센트룸" + 0.012*"비타민" + 0.007*"신랑" + 0.007*"구입" + 0.006*"영양제" + 0.006*"엽산" + 0.004*"추천" + 0.004*"임신" + 0.004*"종합" + 0.004*"복용"
# INFO:gensim.models.ldamodel:topic #1 (0.200): 0.011*"센트룸" + 0.004*"삭제" + 0.004*"임신" + 0.004*"구매" + 0.004*"비타민" + 0.004*"강퇴" + 0.004*"규정" + 0.004*"영양제" + 0.004*"가입" + 0.004*"게시판"
# INFO:gensim.models.ldamodel:topic #2 (0.200): 0.033*"센트룸" + 0.017*"비타민" + 0.009*"종합" + 0.009*"영양제" + 0.005*"멀티" + 0.004*"종합비타민" + 0.004*"건강" + 0.004*"제품" + 0.004*"멀티비타민" + 0.004*"신랑"
# INFO:gensim.models.ldamodel:topic #3 (0.200): 0.018*"센트룸" + 0.012*"비타민" + 0.009*"임신" + 0.008*"철분" + 0.007*"게시판" + 0.007*"규정" + 0.007*"보건소" + 0.007*"엽산" + 0.006*"임산부" + 0.005*"영양제"
# INFO:gensim.models.ldamodel:topic #4 (0.200): 0.065*"센트룸" + 0.026*"비타민" + 0.010*"임신" + 0.010*"종합" + 0.009*"추천" + 0.007*"영양제" + 0.007*"종합비타민" + 0.006*"복용" + 0.006*"엽산" + 0.006*"보건소"
# INFO:gensim.models.ldamodel:topic diff=0.233870, rho=0.447214
# DEBUG:gensim.models.ldamodel:bound: at document #0
# INFO:gensim.models.ldamodel:-8.150 per-word bound, 284.1 perplexity estimate based on a held-out corpus of 2000 documents with 46593 words
# INFO:gensim.models.ldamodel:PROGRESS: pass 4, at document #2000/2000
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1939/2000 documents converged within 50 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:topic #0 (0.200): 0.038*"센트룸" + 0.011*"비타민" + 0.007*"신랑" + 0.007*"구입" + 0.006*"영양제" + 0.006*"엽산" + 0.004*"추천" + 0.004*"종합" + 0.004*"임신" + 0.004*"복용"
# INFO:gensim.models.ldamodel:topic #1 (0.200): 0.010*"센트룸" + 0.004*"삭제" + 0.004*"구매" + 0.004*"강퇴" + 0.004*"가입" + 0.004*"규정" + 0.004*"임신" + 0.004*"게시판" + 0.004*"이동" + 0.004*"비타민"
# INFO:gensim.models.ldamodel:topic #2 (0.200): 0.032*"센트룸" + 0.017*"비타민" + 0.009*"종합" + 0.008*"영양제" + 0.005*"멀티" + 0.004*"건강" + 0.004*"종합비타민" + 0.004*"멀티비타민" + 0.004*"제품" + 0.004*"신랑"
# INFO:gensim.models.ldamodel:topic #3 (0.200): 0.018*"센트룸" + 0.012*"비타민" + 0.009*"임신" + 0.009*"철분" + 0.008*"게시판" + 0.007*"규정" + 0.007*"보건소" + 0.007*"엽산" + 0.006*"임산부" + 0.005*"개월"
# INFO:gensim.models.ldamodel:topic #4 (0.200): 0.066*"센트룸" + 0.027*"비타민" + 0.011*"종합" + 0.011*"임신" + 0.010*"추천" + 0.008*"영양제" + 0.007*"종합비타민" + 0.007*"복용" + 0.006*"엽산" + 0.006*"보건소"
# INFO:gensim.models.ldamodel:topic diff=0.157149, rho=0.408248
# DEBUG:gensim.models.ldamodel:bound: at document #0
# INFO:gensim.models.ldamodel:-8.128 per-word bound, 279.7 perplexity estimate based on a held-out corpus of 2000 documents with 46593 words
# INFO:gensim.models.ldamodel:PROGRESS: pass 5, at document #2000/2000
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1942/2000 documents converged within 50 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:topic #0 (0.200): 0.037*"센트룸" + 0.011*"비타민" + 0.007*"신랑" + 0.007*"구입" + 0.006*"영양제" + 0.006*"엽산" + 0.004*"추천" + 0.004*"종합" + 0.004*"복용" + 0.004*"임신"
# INFO:gensim.models.ldamodel:topic #1 (0.200): 0.009*"센트룸" + 0.004*"삭제" + 0.004*"구매" + 0.004*"강퇴" + 0.004*"가입" + 0.004*"규정" + 0.004*"게시판" + 0.004*"이동" + 0.003*"임신" + 0.003*"광고"
# INFO:gensim.models.ldamodel:topic #2 (0.200): 0.032*"센트룸" + 0.016*"비타민" + 0.008*"종합" + 0.008*"영양제" + 0.005*"멀티" + 0.005*"건강" + 0.004*"멀티비타민" + 0.004*"제품" + 0.004*"종합비타민" + 0.004*"신랑"
# INFO:gensim.models.ldamodel:topic #3 (0.200): 0.018*"센트룸" + 0.011*"비타민" + 0.009*"임신" + 0.009*"철분" + 0.008*"게시판" + 0.008*"규정" + 0.008*"보건소" + 0.007*"엽산" + 0.006*"임산부" + 0.006*"개월"
# INFO:gensim.models.ldamodel:topic #4 (0.200): 0.068*"센트룸" + 0.028*"비타민" + 0.012*"종합" + 0.011*"임신" + 0.010*"추천" + 0.009*"영양제" + 0.008*"종합비타민" + 0.007*"복용" + 0.007*"엽산" + 0.006*"보건소"
# INFO:gensim.models.ldamodel:topic diff=0.109495, rho=0.377964
# DEBUG:gensim.models.ldamodel:bound: at document #0
# INFO:gensim.models.ldamodel:-8.113 per-word bound, 276.9 perplexity estimate based on a held-out corpus of 2000 documents with 46593 words
# INFO:gensim.models.ldamodel:PROGRESS: pass 6, at document #2000/2000
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1949/2000 documents converged within 50 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:topic #0 (0.200): 0.037*"센트룸" + 0.011*"비타민" + 0.007*"신랑" + 0.007*"구입" + 0.006*"영양제" + 0.005*"엽산" + 0.004*"추천" + 0.004*"종합" + 0.004*"복용" + 0.003*"아침"
# INFO:gensim.models.ldamodel:topic #1 (0.200): 0.008*"센트룸" + 0.004*"삭제" + 0.004*"구매" + 0.004*"강퇴" + 0.004*"가입" + 0.004*"이동" + 0.004*"규정" + 0.004*"게시판" + 0.003*"광고" + 0.003*"판매"
# INFO:gensim.models.ldamodel:topic #2 (0.200): 0.031*"센트룸" + 0.016*"비타민" + 0.007*"영양제" + 0.007*"종합" + 0.005*"멀티" + 0.005*"건강" + 0.004*"멀티비타민" + 0.004*"제품" + 0.004*"신랑" + 0.004*"종합비타민"
# INFO:gensim.models.ldamodel:topic #3 (0.200): 0.017*"센트룸" + 0.011*"비타민" + 0.010*"임신" + 0.009*"철분" + 0.008*"게시판" + 0.008*"규정" + 0.008*"보건소" + 0.007*"엽산" + 0.006*"임산부" + 0.006*"개월"
# INFO:gensim.models.ldamodel:topic #4 (0.200): 0.069*"센트룸" + 0.029*"비타민" + 0.012*"종합" + 0.011*"임신" + 0.010*"추천" + 0.010*"영양제" + 0.008*"종합비타민" + 0.007*"엽산" + 0.007*"복용" + 0.006*"수유"
# INFO:gensim.models.ldamodel:topic diff=0.078553, rho=0.353553
# DEBUG:gensim.models.ldamodel:bound: at document #0
# INFO:gensim.models.ldamodel:-8.104 per-word bound, 275.1 perplexity estimate based on a held-out corpus of 2000 documents with 46593 words
# INFO:gensim.models.ldamodel:PROGRESS: pass 7, at document #2000/2000
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1954/2000 documents converged within 50 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:topic #0 (0.200): 0.037*"센트룸" + 0.011*"비타민" + 0.007*"신랑" + 0.007*"구입" + 0.006*"영양제" + 0.005*"엽산" + 0.004*"추천" + 0.004*"복용" + 0.004*"종합" + 0.003*"아침"
# INFO:gensim.models.ldamodel:topic #1 (0.200): 0.008*"센트룸" + 0.004*"삭제" + 0.004*"구매" + 0.004*"강퇴" + 0.004*"가입" + 0.004*"이동" + 0.004*"규정" + 0.004*"게시판" + 0.003*"광고" + 0.003*"판매"
# INFO:gensim.models.ldamodel:topic #2 (0.200): 0.030*"센트룸" + 0.015*"비타민" + 0.007*"영양제" + 0.006*"종합" + 0.005*"멀티" + 0.005*"건강" + 0.004*"멀티비타민" + 0.004*"제품" + 0.004*"신랑" + 0.003*"종합비타민"
# INFO:gensim.models.ldamodel:topic #3 (0.200): 0.017*"센트룸" + 0.011*"비타민" + 0.010*"임신" + 0.009*"철분" + 0.009*"게시판" + 0.009*"규정" + 0.008*"보건소" + 0.007*"엽산" + 0.006*"임산부" + 0.006*"개월"
# INFO:gensim.models.ldamodel:topic #4 (0.200): 0.070*"센트룸" + 0.029*"비타민" + 0.013*"종합" + 0.011*"임신" + 0.010*"영양제" + 0.010*"추천" + 0.008*"종합비타민" + 0.007*"엽산" + 0.007*"복용" + 0.006*"수유"
# INFO:gensim.models.ldamodel:topic diff=0.057692, rho=0.333333
# DEBUG:gensim.models.ldamodel:bound: at document #0
# INFO:gensim.models.ldamodel:-8.097 per-word bound, 273.7 perplexity estimate based on a held-out corpus of 2000 documents with 46593 words
# INFO:gensim.models.ldamodel:PROGRESS: pass 8, at document #2000/2000
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1963/2000 documents converged within 50 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:topic #0 (0.200): 0.036*"센트룸" + 0.010*"비타민" + 0.007*"신랑" + 0.007*"구입" + 0.005*"영양제" + 0.005*"엽산" + 0.004*"추천" + 0.004*"복용" + 0.003*"아침" + 0.003*"종합"
# INFO:gensim.models.ldamodel:topic #1 (0.200): 0.008*"센트룸" + 0.004*"삭제" + 0.004*"강퇴" + 0.004*"구매" + 0.004*"가입" + 0.004*"이동" + 0.004*"게시판" + 0.004*"규정" + 0.003*"광고" + 0.003*"판매"
# INFO:gensim.models.ldamodel:topic #2 (0.200): 0.029*"센트룸" + 0.015*"비타민" + 0.006*"영양제" + 0.006*"종합" + 0.005*"멀티" + 0.005*"건강" + 0.004*"제품" + 0.004*"멀티비타민" + 0.004*"신랑" + 0.003*"걱정"
# INFO:gensim.models.ldamodel:topic #3 (0.200): 0.017*"센트룸" + 0.011*"비타민" + 0.010*"임신" + 0.009*"게시판" + 0.009*"철분" + 0.009*"규정" + 0.008*"보건소" + 0.007*"엽산" + 0.006*"개월" + 0.006*"임산부"
# INFO:gensim.models.ldamodel:topic #4 (0.200): 0.070*"센트룸" + 0.030*"비타민" + 0.013*"종합" + 0.011*"임신" + 0.011*"영양제" + 0.010*"추천" + 0.008*"종합비타민" + 0.007*"엽산" + 0.007*"복용" + 0.006*"수유"
# INFO:gensim.models.ldamodel:topic diff=0.043731, rho=0.316228
# DEBUG:gensim.models.ldamodel:bound: at document #0
# INFO:gensim.models.ldamodel:-8.091 per-word bound, 272.7 perplexity estimate based on a held-out corpus of 2000 documents with 46593 words
# INFO:gensim.models.ldamodel:PROGRESS: pass 9, at document #2000/2000
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1960/2000 documents converged within 50 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:topic #0 (0.200): 0.036*"센트룸" + 0.010*"비타민" + 0.007*"신랑" + 0.007*"구입" + 0.005*"영양제" + 0.005*"엽산" + 0.004*"추천" + 0.004*"복용" + 0.003*"아침" + 0.003*"저희"
# INFO:gensim.models.ldamodel:topic #1 (0.200): 0.007*"센트룸" + 0.004*"삭제" + 0.004*"강퇴" + 0.004*"구매" + 0.004*"가입" + 0.004*"이동" + 0.004*"게시판" + 0.004*"규정" + 0.003*"광고" + 0.003*"판매"
# INFO:gensim.models.ldamodel:topic #2 (0.200): 0.029*"센트룸" + 0.014*"비타민" + 0.006*"영양제" + 0.006*"종합" + 0.005*"멀티" + 0.005*"건강" + 0.004*"제품" + 0.004*"멀티비타민" + 0.004*"신랑" + 0.003*"걱정"
# INFO:gensim.models.ldamodel:topic #3 (0.200): 0.017*"센트룸" + 0.010*"비타민" + 0.010*"임신" + 0.010*"게시판" + 0.009*"규정" + 0.009*"철분" + 0.008*"보건소" + 0.007*"엽산" + 0.006*"개월" + 0.006*"28123090"
# INFO:gensim.models.ldamodel:topic #4 (0.200): 0.071*"센트룸" + 0.030*"비타민" + 0.013*"종합" + 0.011*"영양제" + 0.011*"임신" + 0.011*"추천" + 0.009*"종합비타민" + 0.007*"엽산" + 0.007*"복용" + 0.006*"수유"
# INFO:gensim.models.ldamodel:topic diff=0.034056, rho=0.301511

# %%
resultList
# Out:
# [[('센트룸', 0.03592991),
#   ('비타민', 0.009999723),
#   ('신랑', 0.0069860653),
#   ('구입', 0.0069731176),
#   ('영양제', 0.0053316504),
#   ('엽산', 0.0045930874),
#   ('추천', 0.0036663187),
#   ('복용', 0.0035254005),
#   ('아침', 0.003494382),
#   ('저희', 0.0034433773)],
#  [('센트룸', 0.007265904),
#   ('삭제', 0.0044393847),
#   ('강퇴', 0.004075881),
#   ('구매', 0.004054588),
#   ('가입', 0.0039655087),
#   ('이동', 0.0036640654),
#   ('게시판', 0.0035708887),
#   ('규정', 0.003546025),
#   ('광고', 0.0034874172),
#   ('판매', 0.0032929094)],
#  [('센트룸', 0.028731393),
#   ('비타민', 0.01417563),
#   ('영양제', 0.006173227),
#   ('종합', 0.005518799),
#   ('멀티', 0.005321842),
#   ('건강', 0.0049599344),
#   ('제품', 0.0040876),
#   ('멀티비타민', 0.004013643),
#   ('신랑', 0.0035650802),
#   ('걱정', 0.0032634693)],
#  [('센트룸', 0.016972806),
#   ('비타민', 0.010425429),
#   ('임신', 0.010154084),
#   ('게시판', 0.009652309),
#   ('규정', 0.009478903),
#   ('철분', 0.009327028),
#   ('보건소', 0.008247033),
#   ('엽산', 0.007159252),
#   ('개월', 0.0063428534),
#   ('28123090', 0.006199078)],
#  [('센트룸', 0.0710669),
#   ('비타민', 0.030186662),
#   ('종합', 0.013322528),
#   ('영양제', 0.0112525895),
#   ('임신', 0.01112453),
#   ('추천', 0.0105396975),
#   ('종합비타민', 0.008656403),
#   ('엽산', 0.0074635437),
#   ('복용', 0.0070150774),
#   ('수유', 0.006093934)]]
